# %%
import matplotlib.pyplot as plt
import numpy as np

from coastal_dynamics.sketchapp_question import SketchAppQuestion

# %matplotlib widget

# %%
question_data = {
    'xmin':-100,  
    'xmax':100,
    'ymin':-10,
    'ymax':10,
    
    'answer':5 - (0.02 * np.linspace(-100, 100, 100))**2,
    
    'epsilon':5,
    'lim_to_zero':False,
    
    'xlabel':'X-axis',
    'ylabel':'Y-axis',
    'title':'Left click to add points, right click to remove points',
}

# %%
q = SketchAppQuestion(question_data)

q.draw_figure(
    figsize=(10,5), 
    aspect_ratio=5, 
    N=500
    )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
q.plot_answer()

# %%
q.check_answer()
# Out:
# to be implemented

# %%
q.close()
