# %% [markdown]
# <figure>
#   <IMG SRC="https://raw.githubusercontent.com/mbakker7/exploratory_computing_with_python/master/tudelft_logo.png" WIDTH=250 ALIGN="right">
# </figure>

# %% [markdown]
# ## Answered version

# %%
# %run Initialize/init_3b.ipynb

# %% [markdown]
# ## 3.1) Wave and tidal information

# %% [raw]
# @Judith: Which parameters would you like to be changeable (input widget) for students? And would you like to ask questions. Can I type a narative?

# %% [markdown]
# ### 3.1.1) Superposition of wave components

# %%
W3_fig_5_13()

# %% [markdown]
# ### 3.1.2) Skewed waves

# %%
W3_fig_5_14()

# %%
W3_fig_5_15()

# %% [markdown]
# Can you code 2 wave components that show the same signals over space? You can use the second-order equation for the surface elevation to compute the actual surface elevation. You do not have to divide/scale over the amplitude of wave component one or along the x-axis. Below is a beginning and a function to check your answer. Good luck!

# %%
a1, T1 = 2,5            # the amplitude and period of wave component 1
tp, xp = 0,0            # the time and space location (p = point) of interest (might be relevant)
x = np.arange(0,100,1)  # the x-axis, Show_Q_fig_5_15A() overrules this input, but this might be useful when coding the function

def eta_asymmetric_x(a1, T1, tp, x):
    h = 999 # deep water
    L1 = wave_length(T1, h)
    L2 = 0.5*L1
    T2 = 0.5*T1
    a2 = 0.25*a1
    eta1_x= a1*np.cos(2*np.pi/T1*tp-2*np.pi/L1*x)
    eta2_x= a2*np.cos(2*np.pi/T2*tp-2*np.pi/L2*x+0.5*np.pi)
    eta_x = eta1_x + eta2_x
    return eta_x

Show_eta_asymmetric_x()

# %% [markdown]
# Can you also code 2 wave components over time, while using the second-order equation for the surface elevation to compute the actual surface elevation? You do not have to divide/scale over the amplitude of wave component one or along the x-axis.

# %%
a1, T1 = 1,5            # the amplitude and period of wave component 1
tp, xp = 0,0            # the time and space location (p = point) of interest (might be relevant)
t = np.arange(0,10,0.1) # the x-axis, Show_Q_fig_5_15B() overrules this input, but this might be useful when coding the function

def eta_asymmetric_t(a1, T1, xp, t):
    h = 999 # deep water
    L1 = wave_length(T1, h)
    L2 = 0.5*L1
    T2 = 0.5*T1
    a2 = 0.25*a1
    eta1_T = a1*np.cos(2*np.pi/T1*t-2*np.pi/L1*xp)
    eta2_T = a2*np.cos(2*np.pi/T2*t-2*np.pi/L2*xp+0.5*np.pi)
    eta_T = eta1_T + eta2_T

    return eta_T

Show_eta_asymmetric_t()

# %%
W3_fig_5_16()

# %% [markdown]
# ### 3.1.3) Skewed and asymmetric waves

# %%
W3_fig_5_17()

# %% [markdown]
# Can you code the surface elevation of the skewed waves when the wave phase (S) is defined? You do not have to scale to the amplitude of wave component 1, which is done in figure 5-17.

# %%
a1 = 1                                        # the amplitude of wave component 1
S = np.linspace(-0.25*np.pi, 2.25*np.pi, 60)   # the wave phases that are considered, the x-axis

def eta_skewed_S(a1, S):
    a2 = 0.25*a1
    S1 = S*2
    eta = a1*np.cos(S)+a2*np.cos(S1)
    return eta

Show_eta_skewed_S()

# %% [markdown]
# Can you code the surface elevation of the asymmetic waves when the wave phase (S) is defined? You do not have to scale to the amplitude of wave component 1, which is done in figure 5-17.

# %%
a1 = 1
S = np.linspace(-0.25*np.pi, 2.25*np.pi, 60)

def eta_asymmetric_S(a1, S):
    a2 = 0.25*a1
    S1 = S*2+0.5*np.pi # twice as fast and 90 degrees phase forwarded  
    eta = a1*np.cos(S)+a2*np.cos(S1)
    return eta

Show_eta_asymmetric_S()

# %%
W3_Q1()

# %%
a1 = 1.3 # dont forget to change!

Delta_S = 0.00001
S = np.arange(0, 2*np.pi + Delta_S, Delta_S)  # discretized omega, from 0 to 2 pi.

a2 = 0.25* a1

S1 = S*2 # twice as fast
eta = a1*np.cos(S)+a2*np.cos(S1)
A_skewed = np.sum(eta**3)*Delta_S

S2 = S*2+0.5*np.pi # twice as fast and 90 degrees phase forwarded
eta_As = a1*np.cos(S)+a2*np.cos(S2)
A_asymmetric = np.sum(eta_As**3)*Delta_S

Check_W3_Q1()

# %% [markdown]
# ## 3.2) Wave transformation in the near-shore

# %% [markdown]
# We continue on the application of the dispersion relationship in the cross-shore, which was discussed in week 3 and the Wave course.

# %% [markdown]
# ### 3.2.1) Wave height (H), radiation stress (Sxx), mean water level by waves ($\eta$) for normal incident waves

# %% [markdown]
# In Waves you should have programmed a function to compute the wave height (H), radiation stress (Sxx), and mean water level ($\eta$) along the cross-shore for normal incident waves. Can you reproduce/copy these functions below? If not, you can uncomment the content in the cell below and use this to answer the upcoming questions. However, it is highly recommended to make those functions. As inputs (arguments) you should consider the offshore deep-water wave height (H0), the wave period (T), the offshore water depth (d0) and the bed slope (slope). Below are some wave conditions given. The spatial grid is defined with x_range.
#
# You can use Forward Euler to calculate the derivate, for which an example is shown in the cell below.

# %%
x = x_range  # the horizontal axis
par1 = ...   # known parameter

# Forward Euler to calculate the derivative
for i in range(par1-1):
    dpar1_dx = (par1[i+1] - par1[i])/ (x[i+1]-x[i])

# %%
# This is the code PROVIDED to students.

H0, T, d0, slope = 1.5, 6, 20, 1/30
x_range = np.arange(0,900,1)

def W3_normal_wave_setup(x_range, H0, T, d0, slope):

    # The environmental conditions
    x = x_range               # the horizontal axis
    zbed = -(d0 - slope * x)  # bed elevation [m]
    h = -zbed                 # still water depth [m]
    h[h < 0] = 0              # no negative depths (A depth of 0 can cause warnings, these can be ignored to keep the code straightforward)
    
    # given conditions
    gamma = 0.8               # wave breaking ratio

    '''Complete the code here'''

    return H, Sxx, setup

# This is the answer
H0, T, d0, slope = 1.5, 6, 20, 1/30
x_range = np.arange(0,900,1)
def W3_normal_wave_setup(x_range, H0, T, d0, slope):
    
        # The environmental conditions
        x = x_range               # the horizontal axis
        zbed = -(d0 - slope * x)  # bed elevation [m]
        h = -zbed                 # still water depth [m]
        h[h < 0] = 0              # no negative depths
    
        # given conditions
        gamma = 0.8               # wave breaking ratio

        ''' source: Computerlab by Jaime '''
        
        # The wave characteristics at every location in the cross-section
        L = np.array([wave_length(T, h) for h in h])  # The wavelength
        c = L/T                                       # The wave celerity
        k = 2*np.pi/L                                 # The wave number
        n = 0.5 + (k*h/np.sinh(2*k*h))                
        cg = n*c                                      # The wave group celerity
        Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
        
        H = H0*Ksh                                  # The wave height due to shoaling and refraction
        Hbreaking = gamma * h                         # The wave-breaking height
        H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
        g = 9.81
        E = 1/8*rho*g*H**2                            # The wave energy
    
        Sxx = (2*n-0.5)*E                             # Radiant stresses

        setup = np.zeros(Sxx.shape) # here we create a vector for the mean water level  
        for i in range(len(setup)-1):# key here is that setup[0] = 0 
            setup[i+1] = setup[i] - (Sxx[i+1]-Sxx[i])/(1000*g*h[i])
        
        return H, Sxx, setup

# %% [markdown]
# If you are not able to make the functions, you can uncomment the code below and use this to answer the upcoming coding questions.

# %%
# The numbers will be added later on when the L is defined with an iteration over k.

#x = x_range
#angle = 0 # the offshore wave angle
# Ksh =  # the shoaling parameter
#H = ... # ['getallen',4,65,3,65,34,6,4]
#Sxx = .. # the radiation stress
#eta = ... # surface elevation, with mean-sea-level at 0 m.

# %% [markdown]
# Below is the cross-shore distribution of several wave characteristics shown for the wave conditions described on top. Feel free to study the effects of changing these parameters on the wave characteristics. You can also use these to answer the questions below.

# %% [raw]
# # The first question will be removed, which is: Which method is used to calculate the wavelength?
# # Are there more reflective questions?

# %%
W3_Q4()

# %% [markdown]
# ### 3.2.2) Wave height (H), radiation stress (Sxx), mean water level by waves ($\eta$) for oblique waves

# %% [markdown]
# The influence of refraction should also be considered for waves that approach the shore under an angle. Can you calculate the wave heigth (H), radiation stress (Sxx), and mean water level (eta) for oblique waves by completing the function below? The function W3_plot_oblique_waves(angle1, angle2) will plot these characteristics along the cross-shore for the two given angles. This function will give a runtime warning when the water depth (h) is 0, you may ignore this to keep the code as straightforward as possible.

# %%
# given to students
H0, T, d0, slope, angle = 1.5, 6, 20, 1/30, 20
x_range = np.arange(0,900,1)

def W3_wave_setup(x_range, H0, T, d0, slope, angle):

    ''' you can build on the results from normal-indicent waves'''
    
    return H, Sxx, setup
    

# the answer
def W3_wave_setup(x_range, H0, T, d0, slope, angle):
    
        # The environmental conditions
        x = x_range               # the horizontal axis
        zbed = -(d0 - slope * x)  # bed elevation [m]
        h = -zbed                 # still water depth [m]
        h[h < 0] = 0              # no negative depths
    
        # given conditions
        gamma = 0.8               # wave breaking ratio
        
        # The wave characteristics at every location in the cross-section
        L = np.array([wave_length(T, h) for h in h])  # The wavelength
        c = L/T                                       # The wave celerity
        k = 2*np.pi/L                                 # The wave number
        n = 0.5 + (k*h/np.sinh(2*k*h))                
        cg = n*c                                      # The wave group celerity
        Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
        
        snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
        theta_radians = np.arcsin(snell_constant * c)
        Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5

        
        H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
        Hbreaking = gamma * h                         # The wave-breaking height
        H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
        g = 9.81
        E = 1/8*rho*g*H**2                            # The wave energy
    
        Sxx = (2*n-0.5)*E                             # Radiant stresses
        Sxx = (n-0.5+n*np.cos(theta_radians)**2)*E    # radiant stresses for oblique waves

        ''' Adjusted the code to implement oblique waves, source: Computerlab by Jaime '''
        setup = np.zeros(Sxx.shape) # here we create a vector for the mean water level  
        for i in range(len(setup)-1):# key here is that setup[0] = 0 
            setup[i+1] = setup[i] - (Sxx[i+1]-Sxx[i])/(1000*g*h[i])
        
        return H, Sxx, setup

# %% [raw]
# # Upcoming function, check the answers, now for H, Sxx, and the Setup.

# %% [raw]
# # Upcoming function, it will make 3 graphs, for the wave height, Sxx and eta. Two lines are given, one for each angle.
# W3_plot_oblique_waves(angle1 = 0, angle2 = 45)

# %% [raw]
# --> reflective questions?

# %% [markdown]
# --> reflective questions

# %% [markdown]
# ### 3.2.5) The shorewards directed force (Fx)

# %% [markdown]
# We dive a bit deeper into the force in the cross-shore direction that drives the wave setup (Fx). Can you calculate this force along the cross-shore for an alongshore uniform coast? For this question, you can consider using a similar approach as the setup is calculated, by using forward euler.

# %%
#answer
def W3_Fx(x_range, H0, T, d0, slope, angle):
    
        # The environmental conditions
        x = x_range               # the horizontal axis
        zbed = -(d0 - slope * x)  # bed elevation [m]
        h = -zbed                 # still water depth [m]
        h[h < 0] = 0              # no negative depths
    
        # given conditions
        gamma = 0.8               # wave breaking ratio
        
        # The wave characteristics at every location in the cross-section
        L = np.array([wave_length(T, h) for h in h])  # The wavelength
        c = L/T                                       # The wave celerity
        k = 2*np.pi/L                                 # The wave number
        n = 0.5 + (k*h/np.sinh(2*k*h))                
        cg = n*c                                      # The wave group celerity
        Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
        
        snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
        theta_radians = np.arcsin(snell_constant * c)
        Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5

        
        H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
        Hbreaking = gamma * h                         # The wave-breaking height
        H[H>Hbreaking] = Hbreaking[H>Hbreaking]         # Adjusting the wave height
        g = 9.81
        E = 1/8*rho*g*H**2                            # The wave energy


        #Sxx = (2*n-0.5)*E                             # Radiant stresses for oblique waves
        Sxx = (n-0.5+n*np.cos(theta_radians)**2)*E    # Radiant stresses
        
        setup = np.zeros(Sxx.shape) # here we create a vector for the mean water level  
        for i in range(len(setup)-1):# key here is that setup[0] = 0 
            setup[i+1] = setup[i] - (Sxx[i+1]-Sxx[i])/(1000*g*h[i])

        '''The code above can be replaced with calling the earlier defined function, 
        source: Computerlab by Jaime'''
    
        Fx = np.zeros(Sxx.shape)
        for i in range(len(Fx)-1):
            Fx[i] = -(Sxx[i+1] - Sxx[i])/(x[i+1]-x[i])
        
        return Fx

# %%
W3_plot_Fx()

# %% [raw]
# These and similar plots will be made from a function.

# %%
Fx1 = W3_Fx(x_range, H0, T, d0, slope, angle = 0)
Fx2 = W3_Fx(x_range, H0, T, d0, slope, angle = 45)

# this will be a function
fig, axs = plt.subplots(nrows=2,ncols=1,figsize=(5,4), sharex=True, sharey = False)
axs[0].plot(Fx1, label = 'Fx1')
axs[0].plot(Fx2, label = 'Fx2')
axs[0].legend()
           
z_bed = -(d0 - slope * x_range)
x0_id = np.argwhere(z_bed > 0)[0][0]  # first location where water depth = 0
axs[1].plot(x_range, z_bed, color = 'k', label = 'bed')
axs[1].plot(np.zeros(x0_id), color = 'grey', label = 'still water level' )
axs[1].legend();

# set the limits shown in the graph
axs[0].set_xlim(300,x0_id + 50);

# %% [raw]
# --> Reflective questions

# %% [markdown]
# ### 3.2.6) Alongshore stresses (Syx, Syy) and forces (Fy).

# %% [markdown]
# Can you compute the radiation shear stress in y direction (Syx)?

# %%
def W3_Syx(x_range, H0, T, d0, slope, angle):

    # The environmental conditions
    x = x_range               # the horizontal axis
    zbed = -(d0 - slope * x)  # bed elevation [m]
    h = -zbed                 # still water depth [m]
    h[h < 0] = 0              # no negative depths

    # given conditions
    gamma = 0.8               # wave breaking ratio
    
    # The wave characteristics at every location in the cross-section
    L = np.array([wave_length(T, h) for h in h])  # The wavelength
    c = L/T                                       # The wave celerity
    k = 2*np.pi/L                                 # The wave number
    n = 0.5 + (k*h/np.sinh(2*k*h))                
    cg = n*c                                      # The wave group celerity
    Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
    
    snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
    theta_radians = np.arcsin(snell_constant * c)
    Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5
    
    H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
    Hbreaking = gamma * h                         # The wave-breaking height
    H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
    g = 9.81
    E = 1/8*rho*g*H**2                            # The wave energy

    Syx = n * np.cos(theta_radians) * np.sin(theta_radians)*E
    
    return Syx

# %%
W3_plot_Syx()

# %%
Syx1 = W3_Syx(x_range, H0, T, d0, slope, angle = 0)
Syx2 = W3_Syx(x_range, H0, T, d0, slope, angle = 45)

# this will be a function
fig, axs = plt.subplots(nrows=2,ncols=1,figsize=(5,4), sharex=True, sharey = False)
axs[0].plot(Syx1, label = 'Syx1')
axs[0].plot(Syx2, label = 'Syx2')
axs[0].legend()
           
z_bed = -(d0 - slope * x_range)
x0_id = np.argwhere(z_bed > 0)[0][0]  # first location where water depth = 0
axs[1].plot(x_range, z_bed, color = 'k', label = 'bed')
axs[1].plot(np.zeros(x0_id), color = 'grey', label = 'still water level' )
axs[1].legend();

# set the limits shown in the graph
axs[0].set_xlim(300,x0_id + 50);

# %% [markdown]
# And can you compute the alongshore force (Fy) for an alongshore uniform coast?

# %%
def W3_Fy(x_range, H0, T, d0, slope, angle):

    # The environmental conditions
    x = x_range               # the horizontal axis
    zbed = -(d0 - slope * x)  # bed elevation [m]
    h = -zbed                 # still water depth [m]
    h[h < 0] = 0              # no negative depths

    # given conditions
    gamma = 0.8               # wave breaking ratio
    
    # The wave characteristics at every location in the cross-section
    L = np.array([wave_length(T, h) for h in h])  # The wavelength
    c = L/T                                       # The wave celerity
    k = 2*np.pi/L                                 # The wave number
    n = 0.5 + (k*h/np.sinh(2*k*h))                
    cg = n*c                                      # The wave group celerity
    Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
    
    snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
    theta_radians = np.arcsin(snell_constant * c)
    Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5
    
    H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
    Hbreaking = gamma * h                         # The wave-breaking height
    H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
    g = 9.81
    E = 1/8*rho*g*H**2                            # The wave energy

    Syx = n * np.cos(theta_radians) * np.sin(theta_radians)*E

    Fy = np.zeros(Syx.shape)
    for i in range(len(Fy)-1):
        Fy[i] = - (Syx[i+1] - Syx[i])/(x[i+1]-x[i])
    
    return Fy

# %%
W3_plot_Fy()

# %%
Fy1 = W3_Fy(x_range, H0, T, d0, slope, angle = 0)
Fy2 = W3_Fy(x_range, H0, T, d0, slope, angle = 45)

# The code below will be inside a function
fig, axs = plt.subplots(nrows=2,ncols=1,figsize=(5,4), sharex=True, sharey = False)
axs[0].plot(Fy1, label = 'Fy1')
axs[0].plot(Fy2, label = 'Fy2')
axs[0].legend()
           
z_bed = -(d0 - slope * x_range)
x0_id = np.argwhere(z_bed > 0)[0][0]  # first location where water depth = 0
axs[1].plot(x_range, z_bed, color = 'k', label = 'bed')
axs[1].plot(np.zeros(x0_id), color = 'grey', label = 'still water level' )
axs[1].legend();

# set the limits shown in the graph
axs[0].set_xlim(300,x0_id + 50);

# %% [raw]
# --> reflective questions

# %% [markdown]
# ### 3.2.7) Longshore current

# %% [markdown]
# Can you calculate the distribution of the longshore current, when a bottom roughness (r) of 6 cm is used in the friction factor $c_f$?

# %%
def W3_V(x_range, H0, T, d0, slope, angle, r):

    # The environmental conditions
    x = x_range               # the horizontal axis
    zbed = -(d0 - slope * x)  # bed elevation [m]
    h = -zbed                 # still water depth [m]
    h[h < 0] = 0              # no negative depths

    # given conditions
    gamma = 0.8               # wave breaking ratio
    
    # The wave characteristics at every location in the cross-section
    L = np.array([wave_length(T, h) for h in h])  # The wavelength
    c = L/T                                       # The wave celerity
    k = 2*np.pi/L                                 # The wave number
    n = 0.5 + (k*h/np.sinh(2*k*h))                
    cg = n*c                                      # The wave group celerity
    Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
    
    snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
    theta_radians = np.arcsin(snell_constant * c)
    Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5
    
    H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
    Hbreaking = gamma * h                         # The wave-breaking height
    H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
    g = 9.81
    E = 1/8*rho*g*H**2                            # The wave energy

    #Syx = n * np.cos(theta_radians) * np.sin(theta_radians)*E

    dh_dx = np.zeros(len(h)) # dh/dx
    for i in range(len(dh_dx)-1):
        dh_dx[i] = (h[i+1] - h[i])/(x[i+1]-x[i])

    # page 198
    C = 18*np.log(12)*h/r                     # Chezy coefficient
    c_f = g/C**2                               # friction factor
    
    # formula 5.82 on page 226 of the book
    V = -5/16 * np.pi * gamma / c_f * g * np.sin(theta_radians[0])/c[0]*dh_dx
    V[H != Hbreaking] = 0 # function valid where waves are breaking
    
    return V

# %%
#x_range = np.arange(0,900,1)
W3_plot_V()

# %%
angle1, angle2 = 0, 45
V1 = W3_V(x_range, H0, T, d0, slope, angle1, r)
V2 = W3_V(x_range, H0, T, d0, slope, angle2, r)


# The code below will be inside a function
fig, axs = plt.subplots(nrows=2,ncols=1,figsize=(5,4), sharex=True, sharey = False)
axs[0].plot(V1, label = 'V1')
axs[0].plot(V2, label = 'V2')
axs[0].legend()
           
z_bed = -(d0 - slope * x_range)
x0_id = np.argwhere(z_bed > 0)[0][0]  # first location where water depth = 0
axs[1].plot(x_range, z_bed, color = 'k', label = 'bed')
axs[1].plot(np.zeros(x0_id), color = 'grey', label = 'still water level' )
axs[1].legend();

# set the limits shown in the graph
axs[0].set_xlim(300,x0_id + 50);

# %% [raw]
# --> reflective questions

# %% [markdown]
# ### 3.2.8) Wave induced local current, orbital velocity

# %% [markdown]
# Can you calculate the amplitude of the velocity (u0) near the bed through the linear wave theory?

# %%
def W3_u0(x_range, H0, T, d0, slope, angle):

    # The environmental conditions
    x = x_range               # the horizontal axis
    zbed = -(d0 - slope * x)  # bed elevation [m]
    h = -zbed                 # still water depth [m]
    h[h < 0] = 0              # no negative depths

    # given conditions
    gamma = 0.8               # wave breaking ratio
    
    # The wave characteristics at every location in the cross-section
    L = np.array([wave_length(T, h) for h in h])  # The wavelength
    c = L/T                                       # The wave celerity
    k = 2*np.pi/L                                 # The wave number
    n = 0.5 + (k*h/np.sinh(2*k*h))                
    cg = n*c                                      # The wave group celerity
    Ksh = np.sqrt(cg[0]/cg)                       # The shoaling parameter
    
    snell_constant = np.sin(np.deg2rad(angle))/c[0]  # apply snell's law
    theta_radians = np.arcsin(snell_constant * c)
    Kr = (np.cos(theta_radians[0])/np.cos(theta_radians))**0.5
    
    H = H0*Ksh*Kr                                  # The wave height due to shoaling and refraction
    Hbreaking = gamma * h                         # The wave-breaking height
    H[H>Hbreaking]=Hbreaking[H>Hbreaking]         # Adjusting the wave height
    g = 9.81
    E = 1/8*rho*g*H**2                            # The wave energy

    # page 199 of the book
    omega = 2*np.pi/T
    u0 = 0.5* omega * H / (np.sin(theta_radians)*k*h)
    
    return u0

# %%
W3_plot_u0()

# %%
u0_1 = W3_u0(x_range, H0, T, d0, slope, angle = 0)
u0_2 = W3_u0(x_range, H0, T, d0, slope, angle = 45)

fig, axs = plt.subplots(nrows=2,ncols=1,figsize=(5,4), sharex=True, sharey = False)
axs[0].plot(u0_1, label = 'u0 1')
axs[0].plot(u0_2, label = 'u0 2')
axs[0].legend()
           
z_bed = -(d0 - slope * x_range)
x0_id = np.argwhere(z_bed > 0)[0][0]  # first location where water depth = 0
axs[1].plot(x_range, z_bed, color = 'k', label = 'bed')
axs[1].plot(np.zeros(x0_id), color = 'grey', label = 'still water level' )
axs[1].legend();

# set the limits shown in the graph
axs[0].set_xlim(300,x0_id + 50);

# %% [raw]
# --> reflective questions
