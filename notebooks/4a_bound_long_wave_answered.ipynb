# %% [markdown]
# <figure>
#   <IMG SRC="https://raw.githubusercontent.com/mbakker7/exploratory_computing_with_python/master/tudelft_logo.png" WIDTH=250 ALIGN="right">
# </figure>

# %%
run Initialize/init_4a.ipynb

# %% [markdown]
# # Week 4a: Bound long waves

# %% [markdown]
# Welcome at the first part of week 4, were we use the expression of the wave envelope to compute the fluctuating part of the wavev energy, radiation stress, and the bound long wave.

# %% [markdown]
# ## 1) Wave Envelope

# %% [markdown]
# We discussed the wave envelope in week 2, can you complete the function for the wave envelope below, to continue on this topic in this notebook?

# %%
#2a cos( Delta omega/2  t- Delta k/2 x)

# %% [markdown]
# ## 2) Fluctuating wave energy (E)

# %% [markdown]
# Can you use the expression of the wave envelope to compute the flucutating part of the wave energy?

# %%
# them plot this in space and time by providing a verify and plot button/function

# %% [markdown]
# ## 3) Fluctuating radiant stress (Sxx)

# %% [markdown]
# Can you calculatate the radiant stress (Sxx) that includes that effect of bound long waves?

# %%
# let them plot this in space and time by providing a verify and plot button/function

# %% [markdown]
# ## 4) Bound long wave

# %% [markdown]
# Can you compute the bound long wave surface elevation amplitude, following expression 1, which is Eq. 3.134 in Coastal Morphodynamic modelling guide.
#
# \begin{equation}
# \tag{1}
# \eta_b = \frac{\Delta k^2 ga^2 (2n-0.5)}{\Delta \omega^2-gh\Delta k^2} = \frac{-ga^2(2n-0.5)}{gh-\frac{\Delta \omega^2}{\Delta k^2}} = \frac{-ga^2(2n-0.5)}{gh-c_g^2}
# \end{equation}

# %%
# compute and add it to plots of the group as in the week 3 wave group part

# %% [raw]
# Wave groups continued from week 3 – can be implemented
# •   Link to previous by asking expression of the envelope
# •	From this expression have students code the fluctuating part of the wave energy and radiation stress Sxx and let them plot this in space and time by providing a verify and plot button/function
# •	Compute bound long wave according to Eq. 3.134 in Coastal Morphodynamic modelling guide and add it to plots of the group as in the week 3 wave group part
