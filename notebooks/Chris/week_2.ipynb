# %% [markdown]
# <figure>
#   <IMG SRC="https://raw.githubusercontent.com/mbakker7/exploratory_computing_with_python/master/tudelft_logo.png" WIDTH=250 ALIGN="right">
# </figure>
#
# Before you is the Jupiter Notebook of week 2. This notebook will be incorporated in a Jupiter Book, which has the option to hide the code of the cells.

# %% [markdown]
# # Week 2 Oceanic waves and tide

# %%
# %run Initialize/Week_2_Initialize.ipynb
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='60dc7168-a046-4b2d-ab4e-f61d2fac5628'>
#   <div id="a50fa2cb-a850-436c-9b8d-8e38dc74d7e7" data-root-id="60dc7168-a046-4b2d-ab4e-f61d2fac5628" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b967ddda-e39f-4989-a83f-8a436a39ab7e":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"60dc7168-a046-4b2d-ab4e-f61d2fac5628"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"700247d9-cf8d-4266-bbe7-b2fcf424e323","attributes":{"plot_id":"60dc7168-a046-4b2d-ab4e-f61d2fac5628","comm_id":"d2fa78ee76724a56aa922e1f98e60932","client_comm_id":"55ea58a671d2467e898db85242a948ab"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"b967ddda-e39f-4989-a83f-8a436a39ab7e","roots":{"60dc7168-a046-4b2d-ab4e-f61d2fac5628":"a50fa2cb-a850-436c-9b8d-8e38dc74d7e7"},"root_ids":["60dc7168-a046-4b2d-ab4e-f61d2fac5628"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['katex'] !== undefined) && ( root['MathJax'] !== undefined) && ( root['katex'] !== undefined) && ( root['MathJax'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Packages succesfully loaded

# %% [markdown]
# Wind-generated and tidal waves can travel great distances until they finally reach the coast. In this section, we discuss the propagation of both individual waves and the behaviour of a group of waves together. It is recommended to read chapter ?3? of the book Coastal Dynamics when studying this codebook.

# %% [markdown]
# ## 2.1) pre-knowledge on waves

# %% [markdown]
# This optional section focuses on the material studied in the course waves (CIE....) that is related to the dispersion relationship. We will discuss how the wavelength can be calculated through an iterative approach, by tables, and by an explicit formula. It is recommended to make the calculations at least once manually before these functions are used to answer more complex questions.

# %%
W2_calculators()
# Out:
# Row
#     [0] Column
#         [0] StaticText(value='<span style="font-size: 2...)
#         [1] Row
#             [0] StaticText(value='Solves iteratively:', width=100)
#             [1] LaTeX(str)
#         [2] Row
#             [0] Column
#                 [0] StaticText(value='<b>Input</b>', width=200)
#                 [1] Row
#                     [0] StaticText(value='T', width=1)
#                     [1] FloatInput(step=0.01, value=5, width=100)
#                     [2] StaticText(value='s', width=1)
#                 [2] Row
#                     [0] StaticText(value='h', width=1)
#                     [1] FloatInput(step=0.01, value=3, width=100)
#                     [2] StaticText(value='m', width=1)
#             [1] Column
#                 [0] StaticText(value='<b>Output</b>', width=200)
#                 [1] Row
#                     [0] StaticText(value='L', width=1)
#                     [1] FloatInput(disabled=True, step=0.001, value=24.9316358713127, width=100)
#                     [2] StaticText(value='m', width=1)
#     [1] Column
#         [0] StaticText(value='<span style="font-size: 2...)
#         [1] Row
#             [0] StaticText(value='Solves:', width=100)
#             [1] LaTeX(str)
#         [2] Row
#             [0] Column
#                 [0] StaticText(value='<b>Input</b>', width=200)
#                 [1] Row
#                     [0] StaticText(value='L', width=1)
#                     [1] FloatInput(step=0.01, value=5, width=100)
#                     [2] StaticText(value='m', width=1)
#                 [2] Row
#                     [0] StaticText(value='h', width=1)
#                     [1] FloatInput(step=0.01, value=3, width=100)
#                     [2] StaticText(value='m', width=1)
#             [1] Column
#                 [0] StaticText(value='<b>Output</b>', width=200)
#                 [1] Row
#                     [0] StaticText(value='w', width=1)
#                     [1] FloatInput(disabled=True, step=0.001, value=3.5092039669108583, width=100)
#                     [2] StaticText(value='m', width=1)

# %% [markdown]
# ### 2.1.1) Dispersion relation

# %% [markdown]
# We will discuss how the wavelength can be calculated through an iterative approach, by tables, and by an explicit formula.

# %% [markdown]
# #### Iterative approach

# %%
W2_Q1()
# Out:
# Column
#     [0] StaticText(value='Can you asses t...)
#     [1] Column
#         [0] StaticText(value='a) What is the d..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [2] Column
#         [0] StaticText(value='b) If you use the dispers..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [3] Column
#         [0] StaticText(value='c) To what wavelength d..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)

# %% [markdown]
# #### Wave length through table

# %%
W2_Q2()
# Out:
# Column
#     [0] StaticText(value='Can you asses the wavelen...)
#     [1] Column
#         [0] StaticText(value='a) What is the r..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [2] Column
#         [0] StaticText(value='b) What is the ratio of h..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [3] Column
#         [0] StaticText(value='c) What is the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [4] Column
#         [0] StaticText(value='d) What is the value tanh..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)

# %% [markdown]
# #### Explicit formula

# %%
W2_Q3()
# Out:
# Column
#     [0] StaticText(value='A third method to calcula...)
#     [1] Column
#         [0] StaticText(value='a) What is the wave numbe..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [2] Column
#         [0] StaticText(value='b) What is the wave lengt..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)

# %% [markdown]
# ### 2.1.2) Wave characteristics

# %% [markdown]
# The dispersion relation can be used to calculate and interchange between the wave length and wave period and thereby asses their related parameters. Can you calculate the asked wave characteristics in the questions below?

# %%
W2_Q4()
# Out:
# Column
#     [0] Column
#         [0] StaticText(value='What is the p..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' km/h', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [1] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m/s', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [2] Column
#         [0] StaticText(value='At which speed does the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m/s', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [3] Column
#         [0] StaticText(value='What is the group velocit..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m/s', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [4] Column
#         [0] StaticText(value='What is the value of n wh..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [5] Column
#         [0] StaticText(value='What is the p..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' km/h', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [6] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m/s', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [7] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' m', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)
#     [8] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] FloatInput(step=0.01, width=100)
#             [1] StaticText(value=' s', width=10)
#             [2] Button(name='Check')
#             [3] StaticText(width=500)

# %% [markdown]
# ### 2.1.3) Shallow, intermediate, and deep water

# %% [markdown]
# The wave experiences deep, intermediate, or shallow water conditions. Can you asses which conditions the wave experiences? You can use the cell below for your computations.

# %%
W2_Q5()
# Out:
# StaticText(value='Select if the wave descri...)
# Row
#     [0] StaticText(value='L = 5.05 m, h = 1.25 m', width=150)
#     [1] RadioButtonGroup(name='Radio Button Group', options=['Shallow', 'Intermediate'...], value='Shallow')
# Row
#     [0] StaticText(value='L = 1.72 m, h = 0.62 m', width=150)
#     [1] RadioButtonGroup(name='Radio Button Group', options=['Shallow', 'Intermediate'...], value='Shallow')
# Row
#     [0] StaticText(value='L = 1.08 m, h = 0.72 m', width=150)
#     [1] RadioButtonGroup(name='Radio Button Group', options=['Shallow', 'Intermediate'...], value='Shallow')
# Row
#     [0] StaticText(value='L = 25.33 m, h = 0.77 m', width=150)
#     [1] RadioButtonGroup(name='Radio Button Group', options=['Shallow', 'Intermediate'...], value='Shallow')
# Row
#     [0] StaticText(value='L = 45.63 m, h = 2.0 m', width=150)
#     [1] RadioButtonGroup(name='Radio Button Group', options=['Shallow', 'Intermediate'...], value='Shallow')
# Row
#     [0] Button(name='Check')
#     [1] StaticText(width=500)

# %% [markdown]
# ## 2.2) Dispersion relation for tsunami waves

# %% [markdown]
# The dispersion relation can be used for all kind of waves, including tsunami waves. Can you asses the characteristic for tsunami waves at various water depth classifications?

# %%
W2_Q6()
# Out:
# Column
#     [0] StaticText(value='We are going to analyze t...)
#     [1] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] Column
#                 [0] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' km', width=10)
#                     [2] StaticText(width=250)
#                 [1] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' km', width=10)
#                     [2] StaticText(width=250)
#                 [2] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' km', width=10)
#                     [2] StaticText(width=250)
#                 [3] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' km', width=10)
#                     [2] StaticText(width=250)
#                 [4] Row
#                     [0] Button(name='Check')
#                     [1] StaticText(value='Final score:', width=70)
#                     [2] TextInput(width=130)
#             [1] Matplotlib(Figure, dpi=96)
#     [2] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] Column
#                 [0] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [1] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [2] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [3] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [4] Row
#                     [0] Button(name='Check')
#                     [1] StaticText(value='Final score:', width=70)
#                     [2] TextInput(width=130)
#             [1] Matplotlib(Figure, dpi=96)
#     [3] Column
#         [0] StaticText(value='What is the w..., width=750)
#         [1] Row
#             [0] Column
#                 [0] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [1] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [2] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [3] Row
#                     [0] FloatInput(step=0.01, width=100)
#                     [1] StaticText(value=' m/s', width=10)
#                     [2] StaticText(width=250)
#                 [4] Row
#                     [0] Button(name='Check')
#                     [1] StaticText(value='Final score:', width=70)
#                     [2] TextInput(width=130)
#             [1] Matplotlib(Figure, dpi=96)

# %% [markdown]
# ## 2.3) Dispersion relation in the cross-shore direction

# %% [markdown]
# The water depth can sometimes influence the wave propagation speed, as we have seen in the previous question. There are two types of exceptions, namely deep water and shallow water. In deep water is the depth so large that the orbital velocities of the wave do not reach the bottom and no interaction between the waves and the bed is possible. In this case, the wave celerity is only affected by the wave period. The other extreme is in shallow water, where only the water depth influences the wave celerity, and the wave period is irrelevant. This can lead to waves with the same celerity (non-dispersive waves) even though they have different characteristics. Both of these waves should meet the requirements for shallow water conditions. In other words, although both waves are in the same location, one of them can be in shallow water while the other is not, which results in that both waves have a different celerity.
#
# You check the wavelength and celerity for 3 wave components in the cross-shore direction in the interactive graph below. At the deep water location is the wave celerity constant, then the wave celerity decreases in the intermediate water depth. In one section of the graphs, the celerity for all 3 wave components is equal, which indicates that all the 3 wave components experience shallow water.

# %%
W2_Q7()
# Out:
# HBox(children=(VBox(children=(Label(value='Wave components', layout=Layout(align_self='center')), FloatSlider(…
# Output()
# StaticText(value='Set the graph in the ques...)
# Column
#     [0] StaticText(value='Which of the w...)
#     [1] Row
#         [0] Button(name='Set graph')
#         [1] CheckButtonGroup(name='Check Button Group', options=['wave 1', 'wave 2', ...])
#         [2] Button(name='Check')
#     [2] StaticText()
# Column
#     [0] StaticText(value='Which of the w...)
#     [1] Row
#         [0] Button(name='Set graph')
#         [1] CheckButtonGroup(name='Check Button Group', options=['wave 1', 'wave 2', ...])
#         [2] Button(name='Check')
#     [2] StaticText()
# Column
#     [0] StaticText(value='Which waves a...)
#     [1] Row
#         [0] Button(name='Set graph')
#         [1] CheckButtonGroup(name='Check Button Group', options=['wave 1', 'wave 2', ...])
#         [2] Button(name='Check')
#     [2] StaticText()

# %% [markdown]
# ## 2.4) Wave groups

# %%
# slide 29 (pagina 14 week 3)

# %% [raw]
# # maak code veld
# - commpute:
#
# + delta w, delta k, omega gemmideld, k gemmideld
# + c_average, c_group, Lgroup, Tgroup
# + aantal golven in space (binnen golfgroep) <--
#
# - reflective question
#
# # c_average, reflective question (deze ook berekenen erboven = gemiddelde twee componenten). omega_gemiddeld/k_gemmiddeld. Ongeveer carierwave snelheid.

# %% [markdown]
# Hierna verder hoofdstuk 5, aanhaken Jaime bij Waves Notebook.

# %% [raw]
# def ''
#
#
# function values = answers
#
# load parameters, check specific values
#
# ask questions on the code, what method is used...
#
# 3pn 19th
#
# assert

# %%
try:
    assert 2 == 2
    print(True)
except AssertionError:
    print(False)
# Out:
# True

# %%
def function():

    return

# %%
antwoord_student = function(x==....)
